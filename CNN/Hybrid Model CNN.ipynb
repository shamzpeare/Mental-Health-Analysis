# %%
import pandas as pd
import numpy as np

# %%
file_path = 'Combined Data.csv'
df = pd.read_csv(file_path)
print(df)
class_counts = df["status"].value_counts()

print(class_counts)
# Out:
#        Unnamed: 0                                          statement   status
# 0               0                                         oh my gosh  Anxiety
# 1               1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2               2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3               3  I've shifted my focus to something else but I'...  Anxiety
# 4               4  I'm restless and restless, it's been a month n...  Anxiety
# ...           ...                                                ...      ...
# 53038       53038  Nobody takes me seriously I’ve (24M) dealt wit...  Anxiety
# 53039       53039  selfishness  "I don't feel very good, it's lik...  Anxiety
# 53040       53040  Is there any way to sleep better? I can't slee...  Anxiety
# 53041       53041  Public speaking tips? Hi, all. I have to give ...  Anxiety
# 53042       53042  I have really bad door anxiety! It's not about...  Anxiety
#
# [53043 rows x 3 columns]
# status
# ...

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()
def preprocess_and_tokenize(text):
    if not isinstance(text, str):
        text = ""

    text = re.sub(r'[^A-Za-z0-9\s]', '', text)

    tokens = word_tokenize(text.lower())

    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]

    return lemmatized_tokens

df['tokens'] = df['statement'].apply(preprocess_and_tokenize)

df[['statement', 'tokens']].head()
# Out:
#                                            statement  \
# 0                                         oh my gosh
# 1  trouble sleeping, confused mind, restless hear...
# 2  All wrong, back off dear, forward doubt. Stay ...
# 3  I've shifted my focus to something else but I'...
# 4  I'm restless and restless, it's been a month n...
#
#                                               tokens
# 0                                         [oh, gosh]
# 1  [trouble, sleeping, confused, mind, restless, ...
# 2  [wrong, back, dear, forward, doubt, stay, rest...
# 3  [ive, shifted, focus, something, else, im, sti...
# 4         [im, restless, restless, month, boy, mean]

# %%
# !pip install gensim nltk

# %%
import gensim.downloader as api

word2vec_model = api.load('word2vec-google-news-300')

vector = word2vec_model['computer']
print(f"Vector for 'computer': {vector}")
print(f"Shape of the vector: {vector.shape}")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Vector for 'computer': [ 1.07421875e-01 -2.01171875e-01  1.23046875e-01  2.11914062e-01
#  -9.13085938e-02  2.16796875e-01 -1.31835938e-01  8.30078125e-02
#   2.02148438e-01  4.78515625e-02  3.66210938e-02 -2.45361328e-02
#   2.39257812e-02 -1.60156250e-01 -2.61230469e-02  9.71679688e-02
#  -6.34765625e-02  1.84570312e-01  1.70898438e-01 -1.63085938e-01
#  -1.09375000e-01  1.49414062e-01 -4.65393066e-04  9.61914062e-02
#   1.68945312e-01  2.60925293e-03  8.93554688e-02  6.49414062e-02
#   3.56445312e-02 -6.93359375e-02 -1.46484375e-01 -1.21093750e-01
#  -2.27539062e-01  2.45361328e-02 -1.24511719e-01 -3.18359375e-01
#  -2.20703125e-01  1.30859375e-01  3.66210938e-02 -3.63769531e-02
#  -1.13281250e-01  1.95312500e-01  9.76562500e-02  1.26953125e-01
#   6.59179688e-02  6.93359375e-02  1.02539062e-02  1.75781250e-01
#  -1.68945312e-01  1.21307373e-03 -2.98828125e-01 -1.15234375e-01
# ...

# %%
print(df.columns)  # Check column names
print(df.shape)  # See if dataframe has any rows
print(df['tokens'].head())  # See if tokens are present
# Out:
# Index(['Unnamed: 0', 'statement', 'status', 'tokens'], dtype='object')
# (53043, 4)
# 0                                           [oh, gosh]
# 1    [trouble, sleeping, confused, mind, restless, ...
# 2    [wrong, back, dear, forward, doubt, stay, rest...
# 3    [ive, shifted, focus, something, else, im, sti...
# 4           [im, restless, restless, month, boy, mean]
# Name: tokens, dtype: object

# %%
if df.empty:
    print("DataFrame is empty!")
print(type(df['tokens'].iloc[0]))  # Should be a list
print(df.head())  # See if the dataset was loaded properly
df.head()
# Out:
# <class 'list'>
#    Unnamed: 0                                          statement   status  \
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                               tokens
# 0                                         [oh, gosh]
# 1  [trouble, sleeping, confused, mind, restless, ...
# 2  [wrong, back, dear, forward, doubt, stay, rest...
# 3  [ive, shifted, focus, something, else, im, sti...
# 4         [im, restless, restless, month, boy, mean]
#    Unnamed: 0                                          statement   status  \
# 0           0                                         oh my gosh  Anxiety
# ...

# %%
print("Unique status values before filtering:", df['status'].unique())
# Out:
# Unique status values before filtering: ['Anxiety' 'Normal' 'Depression' 'Suicidal' 'Stress' 'Bipolar'
#  'Personality disorder']

# %%
# Ensure 'status' is a string, handle NaNs, and standardize text
df['status'] = df['status'].astype(str).fillna("").str.strip().str.capitalize()

# Apply filtering
df = df[df['status'].isin(['Depression', 'Suicidal', 'Stress', 'Anxiety', 'Bipolar', 'Personality disorder', 'Normal'])]

# Convert labels
df['status'] = df['status'].map({'Depression': 1, 'Suicidal': 1, 'Stress': 1, 'Anxiety': 1, 'Bipolar':1, 'Personality disorder':1, 'Normal': 0})

# Check the results
print(df['status'].value_counts())
# Out:
# status
# 1    36692
# 0    16351
# Name: count, dtype: int64

# %%
print("Unique status values after filtering:", df['status'].unique())
print("Number of rows after filtering:", df.shape[0])
# Out:
# Unique status values after filtering: [1 0]
# Number of rows after filtering: 53043

# %%
import torch
y_train = torch.tensor(df['status'].values, dtype=torch.float32)
print("y_train tensor shape:", y_train.shape)
# Out:
# y_train tensor shape: torch.Size([53043])

# %%
import numpy as np

def get_average_word2vec(tokens, model, vector_size=300):
    if not isinstance(tokens, list):  # Ensure tokens is a list
        return np.zeros(vector_size)

    vectors = [model[word] for word in tokens if word in model]
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(vector_size)  # Return zero vector if no words are found

df['word2vec_vector'] = df['tokens'].apply(lambda x: get_average_word2vec(x, word2vec_model))
print(df.head())
# Out:
#    Unnamed: 0                                          statement  status  \
# 0           0                                         oh my gosh       1
# 1           1  trouble sleeping, confused mind, restless hear...       1
# 2           2  All wrong, back off dear, forward doubt. Stay ...       1
# 3           3  I've shifted my focus to something else but I'...       1
# 4           4  I'm restless and restless, it's been a month n...       1
#
#                                               tokens  \
# 0                                         [oh, gosh]
# 1  [trouble, sleeping, confused, mind, restless, ...
# 2  [wrong, back, dear, forward, doubt, stay, rest...
# 3  [ive, shifted, focus, something, else, im, sti...
# 4         [im, restless, restless, month, boy, mean]
#
#                                      word2vec_vector
# 0  [0.024963379, 0.012084961, 0.084472656, 0.2368...
# 1  [0.16476004, 0.12486049, -0.02546038, 0.077453...
# ...

# %%
df['status'].value_counts()
# Out:
# status
# 1    36692
# 0    16351
# Name: count, dtype: int64

# %%
import torch
import numpy as np

X = np.stack(df['word2vec_vector'].values)
y = df['status'].values

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

from torch.utils.data import DataLoader, TensorDataset

train_data = TensorDataset(X_train, y_train)
test_data = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %% [markdown]
# **CNN+DT**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

class CNNFeatureExtractor(nn.Module):
    def __init__(self, input_dim, hidden_dim=128):
        super(CNNFeatureExtractor, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.fc = nn.Linear(input_dim * 32, hidden_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class SoftDecisionTree(nn.Module):
    def __init__(self, input_dim, num_classes, num_nodes=10):
        super(SoftDecisionTree, self).__init__()
        self.inner_nodes = nn.Linear(input_dim, num_nodes)
        self.leaf_nodes = nn.Linear(num_nodes, num_classes)

    def forward(self, x):
        decision_weights = torch.sigmoid(self.inner_nodes(x))
        leaf_outputs = self.leaf_nodes(decision_weights)
        return leaf_outputs

class CNNDecisionTree(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes, num_nodes=10):
        super(CNNDecisionTree, self).__init__()
        self.feature_extractor = CNNFeatureExtractor(input_dim, hidden_dim)
        self.decision_tree = SoftDecisionTree(hidden_dim, num_classes, num_nodes)

    def forward(self, x):
        features = self.feature_extractor(x)
        output = self.decision_tree(features)
        return output

def train_model(model, train_loader, test_loader, epochs=10, lr=0.001):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
        train_acc = 100 * correct / total
        print(f"Epoch {epoch+1}, Loss: {total_loss/len(train_loader)}, Train Accuracy: {train_acc:.2f}%")

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

    print(f"Test Accuracy: {100 * correct / total:.2f}%")

input_dim = X_train.shape[1]
num_classes = len(torch.unique(y_train))
model = CNNDecisionTree(input_dim=input_dim, hidden_dim=128, num_classes=num_classes, num_nodes=10)
train_model(model, train_loader, test_loader, epochs=10, lr=0.001)
# Out:
# Epoch 1, Loss: 0.26576212385827963, Train Accuracy: 89.49%
# Epoch 2, Loss: 0.19466316537298514, Train Accuracy: 92.35%
# Epoch 3, Loss: 0.18179964577567223, Train Accuracy: 92.87%
# Epoch 4, Loss: 0.17168389510618806, Train Accuracy: 93.14%
# Epoch 5, Loss: 0.16511913889369167, Train Accuracy: 93.32%
# Epoch 6, Loss: 0.15718649829630463, Train Accuracy: 93.54%
# Epoch 7, Loss: 0.15072196821479328, Train Accuracy: 93.81%
# Epoch 8, Loss: 0.14411751091404457, Train Accuracy: 94.10%
# Epoch 9, Loss: 0.13860481133096386, Train Accuracy: 94.31%
# Epoch 10, Loss: 0.13316932224269223, Train Accuracy: 94.52%
# Test Accuracy: 92.77%

# %% [markdown]
# **CNN + RANDOM FOREST**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

class CNNFeatureExtractor(nn.Module):
    def __init__(self, input_dim, hidden_dim=128):
        super(CNNFeatureExtractor, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.fc = nn.Linear(input_dim * 32, hidden_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class SoftRandomForest(nn.Module):
    def __init__(self, input_dim, num_classes, num_trees=10, tree_depth=3):
        super(SoftRandomForest, self).__init__()
        self.trees = nn.ModuleList([nn.Linear(input_dim, 2 ** tree_depth) for _ in range(num_trees)])
        self.leaf_nodes = nn.Linear(num_trees * (2 ** tree_depth), num_classes)

    def forward(self, x):
        tree_outputs = [torch.sigmoid(tree(x)) for tree in self.trees]
        tree_outputs = torch.cat(tree_outputs, dim=1)
        output = self.leaf_nodes(tree_outputs)
        return output

class CNNRandomForest(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes, num_trees=10, tree_depth=3):
        super(CNNRandomForest, self).__init__()
        self.feature_extractor = CNNFeatureExtractor(input_dim, hidden_dim)
        self.random_forest = SoftRandomForest(hidden_dim, num_classes, num_trees, tree_depth)

    def forward(self, x):
        features = self.feature_extractor(x)
        output = self.random_forest(features)
        return output

def train_model(model, train_loader, test_loader, epochs=10, lr=0.001):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
        train_acc = 100 * correct / total
        print(f"Epoch {epoch+1}, Loss: {total_loss/len(train_loader)}, Train Accuracy: {train_acc:.2f}%")

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

    print(f"Test Accuracy: {100 * correct / total:.2f}%")

input_dim = X_train.shape[1]
num_classes = len(torch.unique(y_train))
model = CNNRandomForest(input_dim=input_dim, hidden_dim=128, num_classes=num_classes, num_trees=10, tree_depth=3)
train_model(model, train_loader, test_loader, epochs=10, lr=0.001)
# Out:
# Epoch 1, Loss: 0.24497797991308443, Train Accuracy: 90.26%
# Epoch 2, Loss: 0.1923389564582007, Train Accuracy: 92.46%
# Epoch 3, Loss: 0.18232274089730047, Train Accuracy: 92.95%
# Epoch 4, Loss: 0.17352482392266674, Train Accuracy: 93.03%
# Epoch 5, Loss: 0.1672352473346268, Train Accuracy: 93.28%
# Epoch 6, Loss: 0.16230524199738952, Train Accuracy: 93.45%
# Epoch 7, Loss: 0.1552788781026026, Train Accuracy: 93.58%
# Epoch 8, Loss: 0.15094142788340364, Train Accuracy: 93.78%
# Epoch 9, Loss: 0.14571000445411647, Train Accuracy: 93.90%
# Epoch 10, Loss: 0.14089130058768118, Train Accuracy: 94.14%
# Test Accuracy: 92.90%

# %% [markdown]
# **CNN+SVM**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

class CNNFeatureExtractor(nn.Module):
    def __init__(self, input_dim, hidden_dim=128):
        super(CNNFeatureExtractor, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.fc = nn.Linear(input_dim * 32, hidden_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class SoftSVM(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(SoftSVM, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

class CNNSVM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(CNNSVM, self).__init__()
        self.feature_extractor = CNNFeatureExtractor(input_dim, hidden_dim)
        self.svm = SoftSVM(hidden_dim, num_classes)

    def forward(self, x):
        features = self.feature_extractor(x)
        output = self.svm(features)
        return output

def hinge_loss(output, target):
    target_one_hot = F.one_hot(target, num_classes=output.shape[1]) * 2 - 1
    loss = torch.mean(torch.clamp(1 - output * target_one_hot, min=0))
    return loss

def train_model(model, train_loader, test_loader, epochs=10, lr=0.001):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = hinge_loss(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()
        train_acc = 100 * correct / total
        print(f"Epoch {epoch+1}, Loss: {total_loss/len(train_loader)}, Train Accuracy: {train_acc:.2f}%")

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

    print(f"Test Accuracy: {100 * correct / total:.2f}%")

input_dim = X_train.shape[1]
num_classes = len(torch.unique(y_train))
model = CNNSVM(input_dim=input_dim, hidden_dim=128, num_classes=num_classes)
train_model(model, train_loader, test_loader, epochs=10, lr=0.001)
# Out:
# Epoch 1, Loss: 0.23992215134568384, Train Accuracy: 90.48%
# Epoch 2, Loss: 0.19685278899796424, Train Accuracy: 92.36%
# Epoch 3, Loss: 0.1876264578250841, Train Accuracy: 92.61%
# Epoch 4, Loss: 0.18180571610884236, Train Accuracy: 92.93%
# Epoch 5, Loss: 0.17654187022480264, Train Accuracy: 93.07%
# Epoch 6, Loss: 0.1726794599224873, Train Accuracy: 93.16%
# Epoch 7, Loss: 0.16794804649423323, Train Accuracy: 93.36%
# Epoch 8, Loss: 0.16679996260201113, Train Accuracy: 93.46%
# Epoch 9, Loss: 0.1615218740397364, Train Accuracy: 93.64%
# Epoch 10, Loss: 0.1583415162079345, Train Accuracy: 93.74%
# Test Accuracy: 92.43%
